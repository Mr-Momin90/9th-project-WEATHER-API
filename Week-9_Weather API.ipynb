# %%
# %%markdown
# # Week 9 Project: Weather App With API
# # Student Name: Abdul Momin Khan
# Out:
# # Week 9 Project: Weather App With API
# # Student Name: Abdul Momin Khan

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in C:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
import requests


URL = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": 25.4,
    "longitude": 68.3,
    "current": "temperature_2m",
}


response = requests.get(URL, params=params)

data = response.json()

print(data)
# Out:
# {'latitude': 25.413004, 'longitude': 68.255684, 'generationtime_ms': 0.023484230041503906, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 21.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C'}, 'current': {'time': '2026-09-13T12:45', 'interval': 900, 'temperature_2m': 38.5}}

# %%
temperature = data["current"]["temperature_2m"] 
print("Temperature:", temperature, "C")
# Out:
# Temperature: 38.5 C

# %%
import requests


print("===== WEATHER APP =====")

# Get location from the user
latitude = float(input("Enter latitude: "))
longitude = float(input("Enter longitude: "))


# Open-Meteo API
URL = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": latitude,
    "longitude": longitude,
    "current": (
        "temperature_2m,"
        "relative_humidity_2m,"
        "wind_speed_10m"
    ),
}


# Send request to the API
response = requests.get(
    URL,
    params=params,
    timeout=10
)


# Process the response
if response.status_code == 200:
    data = response.json()

    temperature = data["current"]["temperature_2m"]
    humidity = data["current"]["relative_humidity_2m"]
    wind = data["current"]["wind_speed_10m"]

    print("\n===== CURRENT WEATHER =====")
    print("Temperature:", temperature, "°C")
    print("Humidity:", humidity, "%")
    print("Wind Speed:", wind, "km/h")

else:
    print("Unable to get weather data.")
# Out:
# ===== WEATHER APP =====
